# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
#
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# Tour going to look the basic usage with jupiter, this notebook it was made for edducational purposes, is a simple and tiny summary, about the basics for data science.
# besides your can see a little of code and marksdowns, as we already said, this is just the beggining, hope your like this project

# %% [markdown]
# ## Some of the popular languages that Data Scientists use are:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# - NumPy
# - Pandas
# - Matplotlib
# - SciPy
# - Scikit-learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## TOOLS OF DATA SCIENCE
#
# | Tools              | Description                        |
# |--------------------|------------------------------------|
# | Jupyter Notebook   | Interactive environment for programing|
# | RStudio            | Environment for the R language     |
# | Apache Spark       | Data Analysis                      |
# | TensorFlow         | library for a deep learning        |
# | RapidMiner         | Data Science Plataform             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers
result = (3 * 4) + 5
result

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hour = minutes/60
hour

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science.
# - Identify major libraries used in Data Science.
# - Demonstrate basic arithmetic operations in Python.
# - Convert units of time from minutes to hours using Python code.
# - Share the notebook publicly on GitHub.

# %% [markdown]
# ## Author
# Brandon Felipe Ortiz Herrera
